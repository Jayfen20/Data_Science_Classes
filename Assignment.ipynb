# %%
##. What percentage of missing or null values exist in key columns such as Description, Directed by, and Written by? How would you handle these missing values?
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df = pd.read_csv('16k_Movies.csv')
df.head()
# Out:
#    Unnamed: 0                     Title  Release Date  \
# 0           0            Dekalog (1988)  Mar 22, 1996
# 1           1         Three Colors: Red  Nov 23, 1994
# 2           2            The Conformist  Oct 22, 1970
# 3           3               Tokyo Story  Mar 13, 1972
# 4           4  The Leopard (re-release)  Aug 13, 2004
#
#                                          Description  Rating  \
# 0  This masterwork by Krzysztof Kieślowski is one...     7.4
# 1  Krzysztof Kieslowski closes his Three Colors t...     8.3
# 2  Set in Rome in the 1930s, this re-release of B...     7.3
# 3  Yasujiro Ozu’s Tokyo Story follows an aging co...     8.1
# 4  Set in Sicily in 1860, Luchino Visconti's spec...     7.8
#
#   No of Persons Voted           Directed by  \
# 0                 118  Krzysztof Kieslowski
# 1                 241  Krzysztof Kieslowski
# 2                 106   Bernardo Bertolucci
# 3                 147          Yasujirô Ozu
# 4                  85      Luchino Visconti
#
#                                           Written by  Duration  \
# 0         Krzysztof Kieslowski, Krzysztof Piesiewicz  9 h 32 m
# 1  Krzysztof Kieslowski, Krzysztof Piesiewicz, Ag...  1 h 39 m
# 2               Alberto Moravia, Bernardo Bertolucci  1 h 47 m
# 3                            Kôgo Noda, Yasujirô Ozu  2 h 16 m
# 4  Giuseppe Tomasi di Lampedusa, Suso Cecchi D'Am...   3 h 7 m
#
#                   Genres
# 0                  Drama
# 1  Drama,Mystery,Romance
# 2                  Drama
# 3                  Drama
# 4          Drama,History

# %%
##. What percentage of missing or null values exist in key columns such as Description, Directed by, and Written by?
missing_values_per = (df.isnull().sum()/ len(df)) * 100
total_missing = df.isnull().sum()
missing_value_outcome = pd.concat([total_missing,missing_values_per], axis =1)
missing_value_outcome
# Out:
#                         0          1
# Unnamed: 0              0   0.000000
# Title                   0   0.000000
# Release Date            0   0.000000
# Description             0   0.000000
# Rating               3444  21.141805
# No of Persons Voted  3461  21.246163
# Directed by             7   0.042971
# Written by            963   5.911602
# Duration               13   0.079804
# Genres                  5   0.030694

# %%
## How would you handle these missing values?
# missing_values_per = (df.fillna().sum()/ len(df)) * 100
# total_missing = df.fillna().sum()
# missing_value_outcome = pd.concat([total_missing,missing_values_per], axis =1)
# missing_value_outcome
df.fillna(5)
# Out:
#        Unnamed: 0                                    Title Release Date  \
# 0               0                           Dekalog (1988)   1996-03-22
# 1               1                        Three Colors: Red   1994-11-23
# 2               2                           The Conformist   1970-10-22
# 3               3                              Tokyo Story   1972-03-13
# 4               4                 The Leopard (re-release)   2004-08-13
# ...           ...                                      ...          ...
# 16285       16285                              Boys to Men   2001-04-27
# 16286       16286  Saint Misbehavin': The Wavy Gravy Movie   2010-12-10
# 16287       16287                               Collectors   2000-10-01
# 16288       16288                               Bonhoeffer   2003-06-20
# 16289       16289                               7th Street   2003-01-17
#
#                                              Description  Rating  \
# 0      This masterwork by Krzysztof Kieślowski is one...     7.4
# 1      Krzysztof Kieslowski closes his Three Colors t...     8.3
# 2      Set in Rome in the 1930s, this re-release of B...     7.3
# 3      Yasujiro Ozu’s Tokyo Story follows an aging co...     8.1
# 4      Set in Sicily in 1860, Luchino Visconti's spec...     7.8
# ...                                                  ...     ...
# 16285  Compilation of 4 short films from different di...     5.0
# 16286  Beginning with Woodstock ‘99, director Michell...     5.0
# 16287  America is drawn to the macabre handiwork of t...     5.0
# 16288  Dramatic documentary about the young German pa...     5.0
# 16289  This documentary explores change in one of the...     5.0
#
#       No of Persons Voted           Directed by  \
# 0                     118  Krzysztof Kieslowski
# 1                     241  Krzysztof Kieslowski
# 2                     106   Bernardo Bertolucci
# 3                     147          Yasujirô Ozu
# 4                      85      Luchino Visconti
# ...                   ...                   ...
# 16285                   5                     5
# 16286                   5       Michelle Esrick
# 16287                   5       Julian P. Hobbs
# 16288                   5      Martin Doblmeier
# 16289                   5             Josh Pais
#
#                                               Written by  \
# 0             Krzysztof Kieslowski, Krzysztof Piesiewicz
# 1      Krzysztof Kieslowski, Krzysztof Piesiewicz, Ag...
# 2                   Alberto Moravia, Bernardo Bertolucci
# 3                                Kôgo Noda, Yasujirô Ozu
# 4      Giuseppe Tomasi di Lampedusa, Suso Cecchi D'Am...
# ...                                                  ...
# 16285                                                  5
# 16286                                                  5
# 16287                                                  5
# 16288                                   Martin Doblmeier
# 16289                                          Josh Pais
#
#                                                 Duration  \
# 0                                               9 h 32 m
# 1                                               1 h 39 m
# 2                                               1 h 47 m
# 3                                               2 h 16 m
# 4                                                3 h 7 m
# ...                                                  ...
# 16285  \n        https://www.amazon.com/Boys-Men-Phil...
# 16286                                          Not Rated
# 16287                                           1 h 20 m
# 16288                                           1 h 33 m
# 16289  \n        http://www.7thstreetmovie.com/\n    ...
#
#                                   Genres  Year of Release  Month of Release  \
# 0                                  Drama             1996                 3
# 1                  Drama,Mystery,Romance             1994                11
# 2                                  Drama             1970                10
# 3                                  Drama             1972                 3
# 4                          Drama,History             2004                 8
# ...                                  ...              ...               ...
# 16285                              Drama             2001                 4
# 16286                        Documentary             2010                12
# 16287                        Documentary             2000                10
# 16288  Documentary,Biography,History,War             2003                 6
# 16289                        Documentary             2003                 1
#
#        Day of Release
# 0                  22
# 1                  23
# 2                  22
# 3                  13
# 4                  13
# ...               ...
# 16285              27
# 16286              10
# 16287               1
# 16288              20
# 16289              17
#
# [14693 rows x 13 columns]

# %%
df.fillna(5)
# Out:
#        Unnamed: 0                                    Title Release Date  \
# 0               0                           Dekalog (1988)   1996-03-22
# 1               1                        Three Colors: Red   1994-11-23
# 2               2                           The Conformist   1970-10-22
# 3               3                              Tokyo Story   1972-03-13
# 4               4                 The Leopard (re-release)   2004-08-13
# ...           ...                                      ...          ...
# 16285       16285                              Boys to Men   2001-04-27
# 16286       16286  Saint Misbehavin': The Wavy Gravy Movie   2010-12-10
# 16287       16287                               Collectors   2000-10-01
# 16288       16288                               Bonhoeffer   2003-06-20
# 16289       16289                               7th Street   2003-01-17
#
#                                              Description  Rating  \
# 0      This masterwork by Krzysztof Kieślowski is one...     7.4
# 1      Krzysztof Kieslowski closes his Three Colors t...     8.3
# 2      Set in Rome in the 1930s, this re-release of B...     7.3
# 3      Yasujiro Ozu’s Tokyo Story follows an aging co...     8.1
# 4      Set in Sicily in 1860, Luchino Visconti's spec...     7.8
# ...                                                  ...     ...
# 16285  Compilation of 4 short films from different di...     5.0
# 16286  Beginning with Woodstock ‘99, director Michell...     5.0
# 16287  America is drawn to the macabre handiwork of t...     5.0
# 16288  Dramatic documentary about the young German pa...     5.0
# 16289  This documentary explores change in one of the...     5.0
#
#       No of Persons Voted           Directed by  \
# 0                     118  Krzysztof Kieslowski
# 1                     241  Krzysztof Kieslowski
# 2                     106   Bernardo Bertolucci
# 3                     147          Yasujirô Ozu
# 4                      85      Luchino Visconti
# ...                   ...                   ...
# 16285                   5                     5
# 16286                   5       Michelle Esrick
# 16287                   5       Julian P. Hobbs
# 16288                   5      Martin Doblmeier
# 16289                   5             Josh Pais
#
#                                               Written by  \
# 0             Krzysztof Kieslowski, Krzysztof Piesiewicz
# 1      Krzysztof Kieslowski, Krzysztof Piesiewicz, Ag...
# 2                   Alberto Moravia, Bernardo Bertolucci
# 3                                Kôgo Noda, Yasujirô Ozu
# 4      Giuseppe Tomasi di Lampedusa, Suso Cecchi D'Am...
# ...                                                  ...
# 16285                                                  5
# 16286                                                  5
# 16287                                                  5
# 16288                                   Martin Doblmeier
# 16289                                          Josh Pais
#
#                                                 Duration  \
# 0                                               9 h 32 m
# 1                                               1 h 39 m
# 2                                               1 h 47 m
# 3                                               2 h 16 m
# 4                                                3 h 7 m
# ...                                                  ...
# 16285  \n        https://www.amazon.com/Boys-Men-Phil...
# 16286                                          Not Rated
# 16287                                           1 h 20 m
# 16288                                           1 h 33 m
# 16289  \n        http://www.7thstreetmovie.com/\n    ...
#
#                                   Genres  Year of Release  Month of Release  \
# 0                                  Drama             1996                 3
# 1                  Drama,Mystery,Romance             1994                11
# 2                                  Drama             1970                10
# 3                                  Drama             1972                 3
# 4                          Drama,History             2004                 8
# ...                                  ...              ...               ...
# 16285                              Drama             2001                 4
# 16286                        Documentary             2010                12
# 16287                        Documentary             2000                10
# 16288  Documentary,Biography,History,War             2003                 6
# 16289                        Documentary             2003                 1
#
#        Day of Release
# 0                  22
# 1                  23
# 2                  22
# 3                  13
# 4                  13
# ...               ...
# 16285              27
# 16286              10
# 16287               1
# 16288              20
# 16289              17
#
# [14693 rows x 13 columns]

# %%
df.fillna(method = 'bfill')
# Out:
# C:\Users\jessi\AppData\Local\Temp\ipykernel_460\3673297803.py:1: FutureWarning:
#
# DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#        Unnamed: 0                                    Title Release Date  \
# 0               0                           Dekalog (1988)   1996-03-22
# 1               1                        Three Colors: Red   1994-11-23
# 2               2                           The Conformist   1970-10-22
# 3               3                              Tokyo Story   1972-03-13
# 4               4                 The Leopard (re-release)   2004-08-13
# ...           ...                                      ...          ...
# 16285       16285                              Boys to Men   2001-04-27
# 16286       16286  Saint Misbehavin': The Wavy Gravy Movie   2010-12-10
# 16287       16287                               Collectors   2000-10-01
# 16288       16288                               Bonhoeffer   2003-06-20
# 16289       16289                               7th Street   2003-01-17
#
#                                              Description  Rating  \
# 0      This masterwork by Krzysztof Kieślowski is one...     7.4
# 1      Krzysztof Kieslowski closes his Three Colors t...     8.3
# 2      Set in Rome in the 1930s, this re-release of B...     7.3
# 3      Yasujiro Ozu’s Tokyo Story follows an aging co...     8.1
# 4      Set in Sicily in 1860, Luchino Visconti's spec...     7.8
# ...                                                  ...     ...
# 16285  Compilation of 4 short films from different di...     NaN
# 16286  Beginning with Woodstock ‘99, director Michell...     NaN
# 16287  America is drawn to the macabre handiwork of t...     NaN
# 16288  Dramatic documentary about the young German pa...     NaN
# 16289  This documentary explores change in one of the...     NaN
#
#       No of Persons Voted           Directed by  \
# 0                     118  Krzysztof Kieslowski
# 1                     241  Krzysztof Kieslowski
# 2                     106   Bernardo Bertolucci
# 3                     147          Yasujirô Ozu
# 4                      85      Luchino Visconti
# ...                   ...                   ...
# 16285                 NaN       Michelle Esrick
# 16286                 NaN       Michelle Esrick
# 16287                 NaN       Julian P. Hobbs
# 16288                 NaN      Martin Doblmeier
# 16289                 NaN             Josh Pais
#
#                                               Written by  \
# 0             Krzysztof Kieslowski, Krzysztof Piesiewicz
# 1      Krzysztof Kieslowski, Krzysztof Piesiewicz, Ag...
# 2                   Alberto Moravia, Bernardo Bertolucci
# 3                                Kôgo Noda, Yasujirô Ozu
# 4      Giuseppe Tomasi di Lampedusa, Suso Cecchi D'Am...
# ...                                                  ...
# 16285                                   Martin Doblmeier
# 16286                                   Martin Doblmeier
# 16287                                   Martin Doblmeier
# 16288                                   Martin Doblmeier
# 16289                                          Josh Pais
#
#                                                 Duration  \
# 0                                               9 h 32 m
# 1                                               1 h 39 m
# 2                                               1 h 47 m
# 3                                               2 h 16 m
# 4                                                3 h 7 m
# ...                                                  ...
# 16285  \n        https://www.amazon.com/Boys-Men-Phil...
# 16286                                          Not Rated
# 16287                                           1 h 20 m
# 16288                                           1 h 33 m
# 16289  \n        http://www.7thstreetmovie.com/\n    ...
#
#                                   Genres  Year of Release  Month of Release  \
# 0                                  Drama             1996                 3
# 1                  Drama,Mystery,Romance             1994                11
# 2                                  Drama             1970                10
# 3                                  Drama             1972                 3
# 4                          Drama,History             2004                 8
# ...                                  ...              ...               ...
# 16285                              Drama             2001                 4
# 16286                        Documentary             2010                12
# 16287                        Documentary             2000                10
# 16288  Documentary,Biography,History,War             2003                 6
# 16289                        Documentary             2003                 1
#
#        Day of Release
# 0                  22
# 1                  23
# 2                  22
# 3                  13
# 4                  13
# ...               ...
# 16285              27
# 16286              10
# 16287               1
# 16288              20
# 16289              17
#
# [14693 rows x 13 columns]

# %%
missing_values_per = (df.isnull().sum()/ len(df)) * 100
total_missing = df.isnull().sum()
missing_value_outcome = pd.concat([total_missing,missing_values_per], axis =1)
missing_value_outcome
# Out:
#                         0          1
# Unnamed: 0              0   0.000000
# Title                   0   0.000000
# Release Date            0   0.000000
# Description             0   0.000000
# Rating               3169  21.568094
# No of Persons Voted  3183  21.663377
# Directed by             7   0.047642
# Written by            894   6.084530
# Duration               13   0.088478
# Genres                  5   0.034030
# Year of Release         0   0.000000
# Month of Release        0   0.000000
# Day of Release          0   0.000000

# %%
## 2. Perform a summary of basic statistics (mean, median, standard deviation, min, and max) for the Rating column. Identify any outliers in movie ratings using statistical methods such as Z-scores or IQR.
df['Rating'].describe()
# Out:
# count    12846.000000
# mean         6.617632
# std          1.415272
# min          0.300000
# 25%          5.800000
# 50%          6.800000
# 75%          7.600000
# max         10.000000
# Name: Rating, dtype: float64

# %%
## Identify any outliers in movie ratings using statistical methods such as Z-scores or IQR
from scipy import stats
z_scores = stats.zscore(df['Rating'])
outliers = df[(z_scores > 3) | (z_scores < -3)]
print(outliers)
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Title, Release Date, Description, Rating, No of Persons Voted, Directed by, Written by, Duration, Genres]
# Index: []

# %%
Q1 = df['Rating'].quantile(0.25)
Q3 = df['Rating'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
outliers_r = df[(df['Rating'] < lower_bound)|(df['Rating'] > upper_bound)]
print(outliers_r)
# Out:
#        Unnamed: 0                          Title Release Date  \
# 156           156  Never Rarely Sometimes Always   2020-03-13
# 262           262                    Wojnarowicz   2021-03-19
# 507           507            Maria Full of Grace   2004-07-16
# 518           518                 The Wicker Man   1974-08-07
# 1436         1436                        Make Up   2020-11-13
# ...           ...                            ...          ...
# 16273       16273                      Strippers   2000-12-08
# 16274       16274                         Vulgar   2002-04-26
# 16276       16276             The Singing Forest   2003-11-14
# 16277       16277    The Garbage Pail Kids Movie   1987-08-22
# 16279       16279                United Passions   2015-06-05
#
#                                              Description  Rating  \
# 156    Faced with an unintended pregnancy and a lack ...     0.9
# 262    Wojnarowicz: F**k You F*ggot F**ker is a fiery...     2.5
# 507    This film follows a bright, gutsy young woman ...     2.0
# 518    A police sergeant is sent to a Scottish island...     2.0
# 1436   On a remote holiday park in Cornwall, a young ...     3.0
# ...                                                  ...     ...
# 16273  Alan is having an horrendous day...he loses hi...     2.7
# 16274  The misadventures of Will, a struggling profes...     2.0
# 16276  Two lovers, killed during the Holocaust, are r...     1.7
# 16277  Dodger must confront the struggles of life as ...     1.0
# 16279  Three men—Jules Rimet (Gérard Depardieu), Joao...     0.8
#
#       No of Persons Voted        Directed by  \
# 156                 1,997      Eliza Hittman
# 262                     4        Chris McKim
# 507                   197     Joshua Marston
# 518                   152        Neil LaBute
# 1436                    7      Claire Oakley
# ...                   ...                ...
# 16273                  16        Jorge Ameer
# 16274                  49      Bryan Johnson
# 16276                  32        Jorge Ameer
# 16277                  21        Rod Amateau
# 16279                 248  Frédéric Auburtin
#
#                                   Written by  Duration  \
# 156                            Eliza Hittman  1 h 41 m
# 262                                      NaN  1 h 45 m
# 507                           Joshua Marston  1 h 41 m
# 518             Neil LaBute, Anthony Shaffer  1 h 42 m
# 1436                           Claire Oakley  1 h 26 m
# ...                                      ...       ...
# 16273                            Jorge Ameer  1 h 11 m
# 16274                          Bryan Johnson  1 h 27 m
# 16276                            Jorge Ameer  1 h 35 m
# 16277  Linda Palmer, Rod Amateau, John Pound  1 h 40 m
# 16279   Frédéric Auburtin, Jean-Paul Delfino  1 h 50 m
#
#                                         Genres  Year of Release  \
# 156                                      Drama             2020
# 262                                Documentary             2021
# 507                                Crime,Drama             2004
# 518                    Horror,Mystery,Thriller             1974
# 1436                    Drama,Mystery,Thriller             2020
# ...                                        ...              ...
# 16273                             Drama,Comedy             2000
# 16274                     Crime,Drama,Thriller             2002
# 16276                    Drama,Fantasy,Romance             2003
# 16277  Adventure,Comedy,Family,Fantasy,Musical             1987
# 16279                      Drama,History,Sport             2015
#
#        Month of Release  Day of Release
# 156                   3              13
# 262                   3              19
# 507                   7              16
# 518                   8               7
# 1436                 11              13
# ...                 ...             ...
# 16273                12               8
# 16274                 4              26
# 16276                11              14
# 16277                 8              22
# 16279                 6               5
#
# [246 rows x 13 columns]

# %%
## 3. How many unique genres exist in the dataset? What are the most common genres over time?
col = df[['Genres']]
for x in col:
    print(df[x].unique())
# Out:
# ['Drama' 'Drama,Mystery,Romance' 'Drama,History' ...
#  'Action,Adventure,Horror' 'Drama,Crime,Action'
#  'Comedy,Crime,Family,Sci-Fi']

# %%
## What are the most common genres over time?
common_genres = df['Genres'].value_counts()
print(common_genres)
# Out:
# Genres
# Drama                                                                     1521
# Documentary                                                               1018
# Comedy,Drama                                                               788
# Comedy,Drama,Romance                                                       644
# Drama,Romance                                                              575
#                                                                           ...
# Animation,Adventure,Comedy,Drama,Family,Fantasy,Mystery,Romance,Sci-Fi       1
# Documentary,Biography,Comedy,Drama,Family                                    1
# Animation,Action,Adventure,Comedy,Crime,Family,Fantasy,Mystery,Sci-Fi        1
# Documentary,Biography,Drama,History,Mystery                                  1
# Comedy,Crime,Family,Sci-Fi                                                   1
# Name: count, Length: 1663, dtype: int64

# %%
## 4. Convert the Release Date column into components like year and month. What are the most frequent movie release years and months?
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16290 entries, 0 to 16289
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           16290 non-null  int64
#  1   Title                16290 non-null  object
#  2   Release Date         16290 non-null  object
#  3   Description          16290 non-null  object
#  4   Rating               12846 non-null  float64
#  5   No of Persons Voted  12829 non-null  object
#  6   Directed by          16283 non-null  object
#  7   Written by           15327 non-null  object
#  8   Duration             16277 non-null  object
#  9   Genres               16285 non-null  object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 1.2+ MB

# %%
df['Release Date'] = pd.to_datetime(df['Release Date'])
df['Year of Release'] = pd.DatetimeIndex(df['Release Date']).year
df['Month of Release'] = pd.DatetimeIndex(df['Release Date']).month
df['Day of Release'] = pd.DatetimeIndex(df['Release Date']).day
df.head()
# Out:
#    Unnamed: 0                     Title Release Date  \
# 0           0            Dekalog (1988)   1996-03-22
# 1           1         Three Colors: Red   1994-11-23
# 2           2            The Conformist   1970-10-22
# 3           3               Tokyo Story   1972-03-13
# 4           4  The Leopard (re-release)   2004-08-13
#
#                                          Description  Rating  \
# 0  This masterwork by Krzysztof Kieślowski is one...     7.4
# 1  Krzysztof Kieslowski closes his Three Colors t...     8.3
# 2  Set in Rome in the 1930s, this re-release of B...     7.3
# 3  Yasujiro Ozu’s Tokyo Story follows an aging co...     8.1
# 4  Set in Sicily in 1860, Luchino Visconti's spec...     7.8
#
#   No of Persons Voted           Directed by  \
# 0                 118  Krzysztof Kieslowski
# 1                 241  Krzysztof Kieslowski
# 2                 106   Bernardo Bertolucci
# 3                 147          Yasujirô Ozu
# 4                  85      Luchino Visconti
#
#                                           Written by  Duration  \
# 0         Krzysztof Kieslowski, Krzysztof Piesiewicz  9 h 32 m
# 1  Krzysztof Kieslowski, Krzysztof Piesiewicz, Ag...  1 h 39 m
# 2               Alberto Moravia, Bernardo Bertolucci  1 h 47 m
# 3                            Kôgo Noda, Yasujirô Ozu  2 h 16 m
# 4  Giuseppe Tomasi di Lampedusa, Suso Cecchi D'Am...   3 h 7 m
#
#                   Genres  Year of Release  Month of Release  Day of Release
# 0                  Drama             1996                 3              22
# 1  Drama,Mystery,Romance             1994                11              23
# 2                  Drama             1970                10              22
# 3                  Drama             1972                 3              13
# 4          Drama,History             2004                 8              13

# %%
## What are the most frequent movie release years and months?
df['Year of Release'].value_counts().sort_values(ascending=False)
# Out:
# Year of Release
# 2014    707
# 2015    687
# 2018    644
# 2013    643
# 2017    640
# 2016    634
# 2019    596
# 2012    586
# 2022    567
# 2020    566
# 2011    566
# 2021    561
# 2006    551
# 2005    529
# 2023    508
# 2004    500
# 2007    485
# 2010    454
# 2002    449
# 2003    437
# 2008    431
# 2009    411
# 2001    400
# 2000    384
# 2024    318
# 1999    277
# 1998    179
# 1997    163
# 1996    156
# 1993    147
# 1995    142
# 1990    137
# 1986    132
# 1992    127
# 1994    124
# 1987    124
# 1989    118
# 1991    111
# 1988    107
# 1985    106
# 1984    101
# 1982     86
# 1981     81
# 1983     79
# 1980     76
# 1979     71
# 1978     58
# 1976     50
# 1973     47
# 1971     45
# 1974     45
# 1977     42
# 1975     41
# 1972     33
# 1970     31
# Name: count, dtype: int64

# %%
df['Month of Release'].value_counts().sort_values(ascending=False)
# Out:
# Month of Release
# 10    1613
# 4     1470
# 3     1457
# 9     1456
# 8     1451
# 11    1385
# 6     1370
# 12    1350
# 5     1345
# 7     1307
# 2     1148
# 1      938
# Name: count, dtype: int64

# %%
## 5. How many duplicate movies exist based on the Title column? What steps would you take to remove duplicates, if any?
df['Title'].duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 16285    False
# 16286    False
# 16287    False
# 16288    False
# 16289    False
# Name: Title, Length: 16290, dtype: bool

# %%
## What steps would you take to remove duplicates, if any?
df['Title'].unique()
# Out:
# array(['Dekalog (1988)', 'Three Colors: Red', 'The Conformist', ...,
#        'Collectors', 'Bonhoeffer', '7th Street'], dtype=object)

# %%
df.drop_duplicates(subset=['Title'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14693 entries, 0 to 16289
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           14693 non-null  int64
#  1   Title                14693 non-null  object
#  2   Release Date         14693 non-null  datetime64[ns]
#  3   Description          14693 non-null  object
#  4   Rating               11524 non-null  float64
#  5   No of Persons Voted  11510 non-null  object
#  6   Directed by          14686 non-null  object
#  7   Written by           13799 non-null  object
#  8   Duration             14680 non-null  object
#  9   Genres               14688 non-null  object
#  10  Year of Release      14693 non-null  int32
#  11  Month of Release     14693 non-null  int32
#  12  Day of Release       14693 non-null  int32
# dtypes: datetime64[ns](1), float64(1), int32(3), int64(1), object(7)
# memory usage: 1.4+ MB

# %%
## 6. Perform frequency counts of categorical columns such as Directed by and Written by. Which directors and screenwriters have the most movies in the dataset?
directed_by_counts = df['Directed by'].value_counts()
written_by_counts = df['Written by'].value_counts()
print(directed_by_counts)
print(written_by_counts)
# Out:
# Directed by
# Woody Allen          39
# Clint Eastwood       35
# Steven Spielberg     32
# Ron Howard           31
# Steven Soderbergh    31
#                      ..
# Michael Rubbo         1
# Shawn Snyder          1
# Nati Baratz           1
# Scott Glosserman      1
# Josh Pais             1
# Name: count, Length: 7379, dtype: int64
# Written by
# Woody Allen                                                          35
# Tyler Perry                                                          19
# Hong Sang-soo                                                        17
# John Hughes                                                          15
# Werner Herzog                                                        14
#                                                                      ..
# Elena Soarez                                                          1
# Bridey Elliott                                                        1
# Tonino Guerra, Michelangelo Antonioni, Wim Wenders, Soheil Ghodsy     1
# Israel Adrián Caetano, Romina Lanfranchini                            1
# Josh Pais                                                             1
# Name: count, Length: 11787, dtype: int64

# %%
## 7. Create a new column that classifies movies based on their Duration (e.g., short, medium, long). How many movies fall into each category, and how does the rating vary by category?
df['Duration'].max()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 ## 7. Create a new column that classifies movies based on their Duration (e.g., short, medium, long). How many movies fall into each category, and how does the rating vary by category?
# ----> 2 df['Duration'].max()
#
# File c:\Users\jessi\anaconda3\Lib\site-packages\pandas\core\series.py:6517, in Series.max(self, axis, skipna, numeric_only, **kwargs)
#    6509 @doc(make_doc("max", ndim=1))
#    6510 def max(
#    6511     self,
#    (...)
#    6515     **kwargs,
#    6516 ):
# -> 6517     return NDFrame.max(self, axis, skipna, numeric_only, **kwargs)
#
# File c:\Users\jessi\anaconda3\Lib\site-packages\pandas\core\generic.py:12404, in NDFrame.max(self, axis, skipna, numeric_only, **kwargs)
#   12397 def max(
#   12398     self,
#   12399     axis: Axis | None = 0,
#    (...)
#   12402     **kwargs,
#   12403 ):
# > 12404     return self._stat_function(
#   12405         "max",
#   12406         nanops.nanmax,
#   12407         axis,
#   12408         skipna,
#   12409         numeric_only,
#   12410         **kwargs,
#   12411     )
#
# File c:\Users\jessi\anaconda3\Lib\site-packages\pandas\core\generic.py:12377, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12373 nv.validate_func(name, (), kwargs)
#   12375 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12377 return self._reduce(
#   12378     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12379 )
#
# File c:\Users\jessi\anaconda3\Lib\site-packages\pandas\core\series.py:6457, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6452     # GH#47500 - change to TypeError to match other methods
#    6453     raise TypeError(
#    6454         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6455         "with non-numeric dtypes."
#    6456     )
# -> 6457 return op(delegate, skipna=skipna, **kwds)
#
# File c:\Users\jessi\anaconda3\Lib\site-packages\pandas\core\nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     145         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File c:\Users\jessi\anaconda3\Lib\site-packages\pandas\core\nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     401 if datetimelike and mask is None:
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#     407     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File c:\Users\jessi\anaconda3\Lib\site-packages\pandas\core\nanops.py:1098, in _nanminmax.<locals>.reduction(values, axis, skipna, mask)
#    1093     return _na_for_min_count(values, axis)
#    1095 values, mask = _get_values(
#    1096     values, skipna, fill_value_typ=fill_value_typ, mask=mask
#    1097 )
# -> 1098 result = getattr(values, meth)(axis)
#    1099 result = _maybe_null_out(result, axis, mask, values.shape)
#    1100 return result
#
# File c:\Users\jessi\anaconda3\Lib\site-packages\numpy\core\_methods.py:41, in _amax(a, axis, out, keepdims, initial, where)
#      39 def _amax(a, axis=None, out=None, keepdims=False,
#      40           initial=_NoValue, where=True):
# ---> 41     return umr_maximum(a, axis, None, out, keepdims, initial, where)
#
# TypeError: '>=' not supported between instances of 'str' and 'float'

# %%
## 8. What are the average and median Number of Persons Voted per movie? What is the relationship between the number of votes and the movie's Rating?
persons_voted = df.groupby('No of Persons Voted').size()
mean_persons_voted = persons_voted.mean()
median_persons_voted = persons_voted.median()
print(f'The mean number of persons voted per movie is {mean_persons_voted}')
print(f'The median number of persons voted per movie is {median_persons_voted}')
# Out:
# The mean number of persons voted per movie is 11.793032786885245
# The median number of persons voted per movie is 2.0

# %%
fig = px.histogram(x = df['No of Persons Voted'], color=df['Rating'], text_auto=True, barmode='group')
fig.show()

# %%
fig = px.histogram(x = df['No of Persons Voted'], color=df['Rating'], facet_col=df['Satisfaction_with_Remote_Work'], text_auto=True, barmode='group')
fig.show()

# %%
print(type('No of Persons Voted' ))
# Out:
# <class 'str'>
